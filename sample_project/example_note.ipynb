# %% [markdown]
# hello

# %% [markdown]
# ##Heart disease project

# %%
import pandas as pd

# %%
df=pd.read_csv("heart-disease.csv")

# %% [markdown]
# the following table shows heart disease information for patients.

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# import matplotlib.pyplot as plt

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# ## 1.problem Definition
# predict heart desease.

# %% [markdown]
# ## 2.Data
# this is the data we are using

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 10C9-ECFD
#
#  Directory of C:\Users\DELL\Desktop\ml\sample_project
#
# 05/11/2026  09:52 PM    <DIR>          .
# 05/11/2026  05:54 AM    <DIR>          ..
# 05/11/2026  08:51 PM    <DIR>          .ipynb_checkpoints
# 05/11/2026  08:44 PM           332,025 6-step-ml-framework.png
# 05/11/2026  06:47 AM    <DIR>          env
# 05/11/2026  08:49 PM               618 exampel_notebook.ipynb
# 05/11/2026  09:52 PM            22,325 example_note.ipynb
# 05/11/2026  08:41 PM            11,328 heart-disease.csv
# 05/11/2026  07:03 PM             2,185 requirements.txt
# 05/11/2026  07:03 AM            21,488 Untitled.ipynb
# 05/11/2026  06:53 PM    <DIR>          venv
#                6 File(s)        389,969 bytes
#                5 Dir(s)  55,643,275,264 bytes free
