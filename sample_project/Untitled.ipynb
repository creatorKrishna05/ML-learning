# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
# !conda create --prefix ./env pandas numpy matplotlib scikit-learn -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\Desktop\ml\sample_project\env
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/win-64::aom-3.13.2-h8ecca34_0
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   ca-certificates    pkgs/main/win-64::ca-certificates-2026.3.19-haa95532_0
#   cairo              pkgs/main/win-64::cairo-1.18.4-he9e932c_0
#   contourpy          pkgs/main/win-64::contourpy-1.3.3-py314h214f63a_0
#   cycler             pkgs/main/win-64::cycler-0.12.1-py314haa95532_0
#   dav1d              pkgs/main/win-64::dav1d-1.5.3-h6ac4d88_0
#   expat              pkgs/main/win-64::expat-2.8.0-hd7fb8db_0
# ...

# %%
conda activate ./env
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate ./env
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install jupyter -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\miniconda3
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyterlab_widgets-3.0.16  |  py313haa95532_1         580 KB
#     ------------------------------------------------------------
#                                            Total:         580 KB
#
# The following NEW packages will be INSTALLED:
#
#   argon2-cffi        pkgs/main/win-64::argon2-cffi-25.1.0-py313haa95532_0
#   argon2-cffi-bindi~ pkgs/main/win-64::argon2-cffi-bindings-25.1.0-py313h02ab6af_0
#   asttokens          pkgs/main/win-64::asttokens-3.0.1-py313haa95532_0
#   async-lru          pkgs/main/win-64::async-lru-2.0.5-py313haa95532_0
# ...
